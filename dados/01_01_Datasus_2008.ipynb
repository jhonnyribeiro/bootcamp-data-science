# %% [markdown]
# <a href="https://colab.research.google.com/github/jhonnyribeiro/bootcamp-data-science/blob/main/dados/01_01_Datasus_2008.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exploração dados Datasus 2008 em diante

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/A112215189_28_143_208.csv", encoding="ISO-8859-1",
                   skiprows=3, sep=";", skipfooter=12,
                   thousands=".", decimal=",")
data.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
#   Unidade da Federação     2008/Jan  ...     2021/Ago         Total
# 0          11 Rondônia   1388528.39  ...  10951319.46  1.073782e+09
# 1              12 Acre    902416.00  ...   4138751.64  4.752903e+08
# 2          13 Amazonas   4735529.42  ...  21752718.52  2.041004e+09
# 3           14 Roraima    657889.53  ...   3781921.16  3.493955e+08
# 4              15 Pará  18864744.11  ...  41160323.18  4.950136e+09
#
# [5 rows x 166 columns]

# %%
data.tail()
# Out:
#      Unidade da Federação     2008/Jan  ...      2021/Ago           Total
# 22   43 Rio Grande do Sul  30931325,46  ...  137579124,29  13503186692,64
# 23  50 Mato Grosso do Sul   5377392,11  ...   36433854,87   2485179285,34
# 24         51 Mato Grosso   4795299,01  ...   36567362,69   2356737844,98
# 25               52 Goiás  15310637,29  ...   68455250,62   5311851612,30
# 26    53 Distrito Federal   4745919,19  ...   27288766,94   2749946630,81
#
# [5 rows x 166 columns]

# %%
data.mean()
# Out:
# 2008/Jan    1.512685e+07
# 2008/Fev    2.271016e+07
# 2008/Mar    2.459419e+07
# 2008/Abr    2.543196e+07
# 2008/Mai    2.651125e+07
#                 ...
# 2021/Abr    7.255846e+07
# 2021/Mai    7.678135e+07
# 2021/Jun    8.003890e+07
# 2021/Jul    7.889588e+07
# Total       6.774439e+09
# Length: 163, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 166 entries, Unidade da Federação to Total
# dtypes: float64(163), object(3)
# memory usage: 35.1+ KB

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
data.mean()
# Out:
# 2008/Jan     15126846.64
# 2008/Fev     22710158.12
# 2008/Mar     24594187.35
# 2008/Abr     25431957.83
# 2008/Mai     26511245.91
#                 ...
# 2021/Abr     72558458.73
# 2021/Mai     76781349.18
# 2021/Jun     80038897.67
# 2021/Jul     78895881.06
# Total      6774438510.94
# Length: 163, dtype: float64

# %%
data["2008/Ago"]
# Out:
# 0      3231494.61
# 1      2089107.14
# 2      9352532.70
# 3       894271.18
# 4     23341218.03
# 5      1475551.38
# 6      5413710.38
# 7     15195312.89
# 8     10549176.40
# 9     27851438.72
# 10    10640817.47
# 11    12872578.37
# 12    35457038.66
# 13     9373432.00
# 14     5238398.50
# 15    46931248.28
# 16    84722528.10
# 17    12588595.77
# 18    50912706.60
# 19   184854516.35
# 20    56982774.90
# 21    31250854.33
# 22    56113054.70
# 23     9671553.45
# 24     9243148.81
# 25    20650730.67
# 26    13710857.89
# Name: 2008/Ago, dtype: float64

# %%
data["2008/Ago"].mean()
# Out:
# 27800320.306666665

# %%
data.plot(x="Unidade da Federação", y="2008/Ago")

# %%
data.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(10,7))
