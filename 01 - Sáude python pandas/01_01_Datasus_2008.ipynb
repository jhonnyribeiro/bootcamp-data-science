# %% [markdown]
# <a href="https://colab.research.google.com/github/jhonnyribeiro/bootcamp-data-science/blob/main/01%20-%20S%C3%A1ude%20python%20pandas/01_01_Datasus_2008.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exploração dados Datasus 2008 em diante

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/A132916189_28_143_208.csv", encoding="ISO-8859-1",
                   skiprows=3, sep=";", skipfooter=12,
                   thousands=".", decimal=",")
data.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
#   Unidade da Federação 1992/Mar  ...     2021/Ago         Total
# 0          11 Rondônia        -  ...   2048596.72  1.073782e+09
# 1              12 Acre        -  ...   1196754.85  4.752903e+08
# 2          13 Amazonas        -  ...   5780705.81  2.041004e+09
# 3           14 Roraima        -  ...   1749906.81  3.493955e+08
# 4              15 Pará        -  ...  13008678.86  4.950136e+09
#
# [5 rows x 292 columns]

# %%
data.tail()
# Out:
#      Unidade da Federação 1992/Mar  ...     2021/Ago         Total
# 22   43 Rio Grande do Sul        -  ...  27963989.54  1.350319e+10
# 23  50 Mato Grosso do Sul        -  ...   3176552.77  2.485179e+09
# 24         51 Mato Grosso        -  ...   9565726.24  2.356738e+09
# 25               52 Goiás        -  ...  21466079.41  5.311850e+09
# 26    53 Distrito Federal        -  ...  11505510.19  2.749947e+09
#
# [5 rows x 292 columns]

# %%
data.mean()
# Out:
# 2007/Ago    3.049528e+05
# 2007/Set    7.881453e+05
# 2007/Out    2.440163e+06
# 2007/Nov    5.517354e+06
# 2007/Dez    1.233716e+07
#                 ...
# 2021/Abr    7.752316e+07
# 2021/Mai    8.140161e+07
# 2021/Jun    6.743630e+07
# 2021/Jul    4.745275e+07
# Total       6.774431e+09
# Length: 169, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 292 entries, Unidade da Federação to Total
# dtypes: float64(169), object(123)
# memory usage: 61.7+ KB

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
data.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2021/Abr     77523160.28
# 2021/Mai     81401610.00
# 2021/Jun     67436298.31
# 2021/Jul     47452748.71
# Total      6774431164.65
# Length: 169, dtype: float64

# %%
data["2008/Ago"]
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
data["2008/Ago"].mean()
# Out:
# 26643557.7262963

# %%
data.plot(x="Unidade da Federação", y="2008/Ago")

# %%
data.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(10,7))

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ax = data.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(10,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
#plt.title("Valor em milhões por unidade da federação no ano/mês")
ax.set_title("Valor em milhões por unidade da federação no ano/mês")
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ax = data.plot(x="Unidade da Federação", y="2021/Jul", kind="bar", figsize=(10,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
#plt.title("Valor em milhões por unidade da federação no ano/mês")
ax.set_title("Valor em milhões por unidade da federação no ano/mês")
plt.show()

# %%
data[["2008/Ago", "2008/Set"]].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
data.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2021/Abr     77523160.28
# 2021/Mai     81401610.00
# 2021/Jun     67436298.31
# 2021/Jul     47452748.71
# Total      6774431164.65
# Length: 169, dtype: float64

# %%
filled_columns = data.mean().index.tolist()
filled_columns.insert(0, "Unidade da Federação")
filled_columns
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
# ...

# %%
data_filled = data[filled_columns]
data_filled.head()
# Out:
#   Unidade da Federação  2007/Ago  ...    2021/Jul         Total
# 0          11 Rondônia   4209.37  ...  7427454.01 1073782138.81
# 1              12 Acre  10470.07  ...  2302711.01  475290315.34
# 2          13 Amazonas  35752.72  ... 16487221.12 2041003727.86
# 3           14 Roraima   4785.91  ...  2977820.70  349395453.66
# 4              15 Pará 181159.29  ... 30176865.99 4950135530.02
#
# [5 rows x 170 columns]

# %%
data_filled = data_filled.set_index("Unidade da Federação")

# %%
data_filled['2019/Ago'].head()
# Out:
# Unidade da Federação
# 11 Rondônia    8909111.89
# 12 Acre        2981072.98
# 13 Amazonas   16493719.52
# 14 Roraima     3181321.82
# 15 Pará       36462011.47
# Name: 2019/Ago, dtype: float64

# %%
data_filled.loc["12 Acre"]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2021/Abr     5002272.59
# 2021/Mai     4326882.24
# 2021/Jun     3458187.11
# 2021/Jul     2302711.01
# Total      475290315.34
# Name: 12 Acre, Length: 169, dtype: float64

# %%
data_filled.T.plot(figsize=(12,6))

# %%
data_filled = data_filled.drop("Total", axis=1)

# %%
data_filled.T.plot(figsize=(12,6))
